# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
shape, scale = 2.0, 2.0
r_variates = np.random.gamma(shape, scale, 1000)

# %%
plt.hist(r_variates, bins=100)
plt.xlabel("Value")
plt.ylabel("Count")

plt.savefig("session10.pdf")

plt.show()
