# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
r_nums = np.random.uniform(0, 1, 1000)

# %%
plt.hist(r_nums, bins=100)
plt.xlabel("Value")
plt.ylabel("Frequency")

plt.savefig("session9.pdf")

plt.show()
